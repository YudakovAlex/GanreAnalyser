# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
import pandas as pd
import os
import subprocess
import sys

# %%
folder = "/home/shad/Projects/GanreAnalizer/Samples/wav/"
files = [
        "Master_Exploder.wav",
        "Dragonbourn.wav",
        "No_Educcation.wav",
        "TNT.wav",
        "Too_Much_To-_Young.wav",
        "Your_Time_Has_Come.wav"
        ]

# %%
for f in files:
    print(f)
    fs, data = wavfile.read(folder + f)
    df_data = pd.DataFrame(data)
    df_data['max'] = df_data.max(axis=1)
    #print(df_data.describe())
    buckets = pd.cut(df_data['max'],10)
    tone_repetitions = df_data.groupby('max').size()
    df_data['1k group'] = pd.Series(df_data['max']/1000).astype(int)
    size_of_1k = df_data.groupby('1k group').size()
    
    plt.plot(size_of_1k)
    plt.show()

# %%
def get_all_mp3s(path):
    "Function to get all mp3s from the path"
    w = os.walk(path)
    # folder / subfolders / files
    all_files = []
    for sw in w:
        all_files += [sw[0] + "/" + x for x in sw[2]]
    mp3_files = []
    for f in all_files:
        if f.split(".")[-1].upper() == "MP3":
            mp3_files.append(f)
    return mp3_files

# %%
path = "/home/shad/Projects/GanreAnalizer/Samples"
#path = "/media/shad/DATA/MuzAnalysis/3 Doors Down"
mp3_files = get_all_mp3s(path)
print(mp3_files)
# Out:
# ['/home/shad/Projects/GanreAnalizer/Samples/DB.mp3', '/home/shad/Projects/GanreAnalizer/Samples/mp3/05-T.N.T..mp3', '/home/shad/Projects/GanreAnalizer/Samples/mp3/01 Your Time Has Come.mp3', '/home/shad/Projects/GanreAnalizer/Samples/mp3/02 No Education.mp3', '/home/shad/Projects/GanreAnalizer/Samples/mp3/07-tenacious_d-master_exploder.mp3', '/home/shad/Projects/GanreAnalizer/Samples/mp3/03_Airbourne-Too Much, Too Young, Too Fast - Airbourne.mp3']

# %%
def convert_mp3_to_wav(filename_mp3, filename_wav=None):
    cd = os.getcwd()
    if not filename_wav: 
        filename_wav =  ".".join(filename_mp3.split(".")[0:-1]) + ".wav"
    if "/" not in filename_wav: cd + "/" + filename_wav
    if "/" not in filename_mp3: cd + "/" + filename_mp3
    subprocess.run(["mpg321", "-w", filename_wav, filename_mp3])
    return filename_wav

# %%
def get_wav_data(file):
    fs, data = wavfile.read(file)
    df_data = pd.DataFrame(data)
    df_data['max'] = df_data.max(axis=1)
    #buckets = pd.cut(df_data['max'],10)
    #tone_repetitions = df_data.groupby('max').size()
    df_data['1k group'] = pd.Series(df_data['max']/1000).astype(int)
    size_of_1k = df_data.groupby('1k group').size()
    return size_of_1k
    #plt.plot(size_of_1k)
    #plt.show()

# %%
for mp3_file in get_all_mp3s("/media/shad/DATA/MuzAnalysis/3 Doors Down"):
    wav_data = get_wav_data(convert_mp3_to_wav(mp3_file))
    plt.plot(wav_data)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-62dabd6cd38a> in <module>
#       1 for mp3_file in get_all_mp3s("/media/shad/DATA/MuzAnalysis/3 Doors Down"):
# ----> 2     wav_data = get_wav_data(convert_mp3_to_wav(mp3_file))
#       3     plt.plot(wav_data)
#       4     plt.show()
#
# <ipython-input-37-2cc15ae97f8b> in convert_mp3_to_wav(filename_mp3, filename_wav)
#       5     if "/" not in filename_wav: cd + "/" + filename_wav
#       6     if "/" not in filename_mp3: cd + "/" + filename_mp3
# ----> 7     subprocess.run(["mpg321", "-w", filename_wav, filename_mp3])
#       8     return filename_wav
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     466     with Popen(*popenargs, **kwargs) as process:
#     467         try:
# --> 468             stdout, stderr = process.communicate(input, timeout=timeout)
#     469         except TimeoutExpired:
#     470             process.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     923                 stderr = self.stderr.read()
#     924                 self.stderr.close()
# --> 925             self.wait()
#     926         else:
#     927             if timeout is not None:
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#     982             endtime = _time() + timeout
#     983         try:
# --> 984             return self._wait(timeout=timeout)
#     985         except KeyboardInterrupt:
#     986             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1616                         if self.returncode is not None:
#    1617                             break  # Another thread waited.
# -> 1618                         (pid, sts) = self._try_wait(0)
#    1619                         # Check the pid and loop as waitpid has been known to
#    1620                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1574             """All callers to this function MUST hold self._waitpid_lock."""
#    1575             try:
# -> 1576                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1577             except ChildProcessError:
#    1578                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
